# %% [markdown]
# <div>
#     <img src="https://cdni.iconscout.com/illustration/premium/thumb/stock-market-growth-5788121-4849094.png?f=webp" alt="Nobel Prize" width="350" align="left" hspace="10">
#     <h1>Tehran Stock Exchange</h1>
# </div>

# %% [markdown]
# ### Download File

# %%
import requests
import pathlib
import pandas as pd
import jdatetime
from tqdm import tqdm
from loguru import logger

# %%
def url_genrator(jalali_date):
    excel_url = f"http://members.tsetmc.com/tsev2/excel/MarketWatchPlus.aspx?d={jalali_date}"
    return excel_url

save_path = "MarketWatchPlus.xlsx"

# %%
def url_downloader(excel_url, save_path):
    
    response = requests.get(excel_url)
    if response.status_code == 200:
        with open(save_path, 'wb') as file:
            file.write(response.content)
        logger.info(f"Download successful. File saved at: {save_path}")
    else:
        logger.info(f"Failed to download. Status code: {response.status_code}")
        
        
def change_format_to_csv(excel_path, save_path):
    
    df = pd.read_excel(excel_path, skiprows=2)
    
    if df.shape != 0:
        df.to_csv(save_path,encoding="utf-8", index=False)
        logger.info(f"format changed successfully!")

# %%
def download_tehran_stock_exchange_files(start_date, end_date, delete_excel=True):
    start_date = jdatetime.datetime.strptime(start_date, format="%Y-%m-%d").date()
    end_date = jdatetime.datetime.strptime(end_date, format="%Y-%m-%d").date()
    
    interval = (end_date - start_date).days
    for i in tqdm(range(0,interval+1)):
        jalali_date = start_date + jdatetime.timedelta(days=i)
        if jalali_date.weekday() not in (5,6):
            url = url_genrator(jalali_date=jalali_date.__str__())
            url_downloader(excel_url=url, save_path=f"./datalake/tehran_stock_exchange_{jalali_date.__str__()}.xlsx")
    
            change_format_to_csv(f"./datalake/tehran_stock_exchange_{jalali_date.__str__()}.xlsx",f"./datalake/tehran_stock_exchange_{jalali_date.__str__()}.csv")
    
    if delete_excel:
        excel_file_path = pathlib.Path(f"./datalake/tehran_stock_exchange_{jalali_date.__str__()}.xlsx")

        # Check if the file exists before attempting to delete
        if excel_file_path.exists():
            try:
                # Delete the file
                excel_file_path.unlink()
                print(f"{excel_file_path} has been deleted successfully.")
            except Exception as e:
                print(f"Error deleting {excel_file_path}: {e}")
        else:
            print(f"The file {excel_file_path} does not exist.")

# %%
download_tehran_stock_exchange_files("1402-9-1", "1402-9-6")
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]2024-01-19 04:06:24.436 | INFO     | __main__:url_downloader:7 - Download successful. File saved at: ./datalake/tehran_stock_exchange_1402-09-01.xlsx
# 2024-01-19 04:06:24.760 | INFO     | __main__:change_format_to_csv:18 - format changed successfully!
#  17%|█▋        | 1/6 [00:12<01:04, 12.96s/it]2024-01-19 04:06:37.573 | INFO     | __main__:url_downloader:7 - Download successful. File saved at: ./datalake/tehran_stock_exchange_1402-09-04.xlsx
# 2024-01-19 04:06:37.837 | INFO     | __main__:change_format_to_csv:18 - format changed successfully!
#  67%|██████▋   | 4/6 [00:26<00:11,  5.99s/it]2024-01-19 04:06:50.301 | INFO     | __main__:url_downloader:7 - Download successful. File saved at: ./datalake/tehran_stock_exchange_1402-09-05.xlsx
# 2024-01-19 04:06:50.570 | INFO     | __main__:change_format_to_csv:18 - format changed successfully!
#  83%|████████▎ | 5/6 [00:38<00:07,  7.87s/it]2024-01-19 04:07:03.463 | INFO     | __main__:url_downloader:7 - Download successful. File saved at: ./datalake/tehran_stock_exchange_1402-09-06.xlsx
# 2024-01-19 04:07:03.766 | INFO     | __main__:change_format_to_csv:18 - format changed successfully!
# 100%|██████████| 6/6 [00:51<00:00,  8.66s/it]
# datalake/tehran_stock_exchange_1402-09-06.xlsx has been deleted successfully.

# %%
# pip install jdatetime

# %% [markdown]
# ### Change Format to CSV

# %%
def change_format_to_csv(excel_path, save_path):
    
    df = pd.read_excel(excel_path, skiprows=2)
    df.to_csv(save_path,encoding="utf-8", index=False)
    logger.info(f"format changed successfully!")

# %% [markdown]
# ### Store CSV file in DataLake

# %%
def create_folders():
    # Stage Folder
    data_dir = pathlib.Path(f'./stage')
    data_dir.mkdir(parents=True, exist_ok=True)
    
    # Data Lake Foler
    data_dir = pathlib.Path(f'./datalake')
    data_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Read CSV file

# %%
pd.read_csv("t1.csv")
# Out:
#            نماد                             نام  تعداد        حجم  \
# 0          اهرم    صندوق س سهامي كاريزما- اهرمي  13886  169217134
# 1         ياقوت         صندوق س ياقوت آگاه-ثابت  11434  261132199
# 2         حفارس  حمل و نقل بين المللي خليج فارس  10251  715665409
# 3      دارا يكم   صندوق واسطه گري مالي يكم-سهام  10116    8272462
# 4         ثشاهد             سرمايه‌ گذاري‌ شاهد   9774   68284768
# ...         ...                             ...    ...        ...
# 1275  طكارا1002     اختيارف كارا-16497-14021027      1        111
# 1276   ضسلا1221   اختيارخ سلام-20000-1402/12/16      1          1
# 1277   ضخوز1036    اختيارخ فخوز-3750-1402/10/17      1         14
# 1278   ضترا1160   اختيارخ شتران-6500-1402/11/23      1          8
# 1279   ضسپا1011   اختيارخ خساپا-5500-1402/10/20      1          1
#
#                ارزش   دیروز   اولین  آخرین معامله - مقدار  \
# 0     3619838332400   21100   21580                 21130
# 1     5521695017303   21117   21145                 21146
# 2     1437830199036    1915    2010                  2000
# 3     1515934757670  178760  182590                183600
# 4     1211143431780   16830   16990                 17560
# ...             ...     ...     ...                   ...
# 1275         111000       1       1                     1
# 1276         485000     600     485                   485
# 1277         700000      40      50                    50
# 1278         280000       1      35                    35
# 1279           1000       1       1                     1
#
#       آخرین معامله - تغییر  آخرین معامله - درصد  قیمت پایانی - مقدار  \
# 0                       30                 0.14                21390
# 1                       29                 0.14                21145
# 2                       85                 4.44                 2009
# 3                     4840                 2.71               183250
# 4                      730                 4.34                17740
# ...                    ...                  ...                  ...
# 1275                     0                 0.00                    1
# 1276                  -115               -19.17                  485
# 1277                    10                25.00                   50
# 1278                    34              3400.00                   35
# 1279                     0                 0.00                    1
#
#       قیمت پایانی - تغییر  قیمت پایانی - درصد  کمترین  بیشترین
# 0                     290                1.37   21080    21810
# 1                      28                0.13   21145    21147
# 2                      94                4.91    1990     2010
# 3                    4490                2.51  181720   184890
# 4                     910                5.41   16990    18000
# ...                   ...                 ...     ...      ...
# 1275                    0                0.00       1        1
# 1276                 -115              -19.17     485      485
# 1277                   10               25.00      50       50
# 1278                   34             3400.00      35       35
# 1279                    0                0.00       1        1
#
# [1280 rows x 15 columns]

# %%
# df.dtypes
# df.nunique()
# df.isna().sum()
# df.duplicated().sum()
# df[df['نام'].duplicated(keep=False)].sort_values('نام')
# df[~df['نماد'].str.isalpha()]
# df[df['تعداد'] < 10]

# %%
jdatetime.datetime.strptime("1402-10-28", format="%Y-%m-%d").weekday() in (5,6)
# Out:
# True
